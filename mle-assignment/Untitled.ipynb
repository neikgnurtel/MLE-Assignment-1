# %%
import pandas as pd

tables = ["clickstream", "attributes", "financials", "lms"]

for t in tables:
    print(f"\n===== {t.upper()} =====")
    df = pd.read_parquet(f"datamart/silver/{t}.parquet")
    print(df.shape)           # số dòng, số cột
    print(df.dtypes.head())   # kiểu dữ liệu 5 cột đầu
    print(df.head(3))         # 3 dòng đầu
# Out:
# ===== CLICKSTREAM =====
# (215376, 22)
# fe_1    int64
# fe_2    int64
# fe_3    int64
# fe_4    int64
# fe_5    int64
# dtype: object
#    fe_1  fe_2  fe_3  fe_4  fe_5  fe_6  fe_7  fe_8  fe_9  fe_10  ...  fe_13  \
# 0    63   118    80   121    55   193   111   112  -101     83  ...    -16
# 1  -108   182   123     4   -56    27    25    -6   284    222  ...    -14
# 2   -13     8    87   166   214   -98   215   152   129    139  ...     26
#
#    fe_14  fe_15  fe_16  fe_17  fe_18  fe_19  fe_20  customer_id  snapshot_date
# 0    -81   -126    114     35     85    -73     76   CUS_0x1037     2023-01-01
# 1    -96    200     35    130     94    111     75   CUS_0x1069     2023-01-01
# 2     86    171    125   -130    354     17    302   CUS_0x114a     2023-01-01
#
# [3 rows x 22 columns]
#
# ===== ATTRIBUTES =====
# (12500, 6)
# customer_id    object
# name           object
# age            object
# ssn            object
# occupation     object
# dtype: object
# ...
